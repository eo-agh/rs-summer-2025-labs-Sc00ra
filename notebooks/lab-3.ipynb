# %% [markdown]
# # Exercise: Create a Python Package for Cloud-Free Mosaics

# %% [markdown]
# In this exercise, your goal is to:
#
# 1. Create a function that generates a cloud-free mosaic using Sentinel-2 data and Google Earth Engine.
# 2. Turn this function into a reusable Python package.
# 3. Organize your code using proper Python package structure.
# 4. Install your package locally in editable mode.
# 5. Test your package using a script or notebook.

# %% [markdown]
# ## Step 1: Write the Function
# Create a function called `create_cloud_free_mosaic(aoi, start_date, end_date)` that:
# - Filters Sentinel-2 imagery by date and area,
# - Applies a cloud mask using the `QA60` band,
# - Returns a cloud-free median composite.

# %% [markdown]
# ## Step 2: Create the Package Structure
# Use the following folder layout:
#
# ```
# geoapps/
# ├── geoapps/
# │   ├── __init__.py
# │   └── lab03/
# │       ├── __init__.py
# │       └── cloud_mosaic.py  # <- your function goes here
# ├── pyproject.toml
# └── README.md
# ```

# %% [markdown]
# ## Step 3: Create `pyproject.toml`
# Use the following template:
#
# ```toml
# [build-system]
# requires = ["setuptools", "wheel"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "geoapps"
# version = "0.1.0"
# requires-python = ">=3.10"
# description = "EO utilities for cloud-free mosaics"
# authors = [
#   { name = "Your Name", email = "your@email.com" }
# ]
#
# [tool.setuptools.packages.find]
# where = ["."]
# exclude = ["tests", "notebooks"]
# ```

# %% [markdown]
# ## Step 4: Install Your Package
# From the root of your project (where `pyproject.toml` is located), run:
#
# ```bash
# pip install -e .
# ```

# %% [markdown]
# ## Step 5: Test the Package
# Create a test script or notebook and try importing your function like this:
#
# ```python
# from geoapps.lab03.cloud_mosaic import create_cloud_free_mosaic
#
# import ee
# ee.Initialize(project='your-ee-project-id')
#
# aoi = ee.Geometry.Rectangle([19.8, 50.0, 20.0, 50.2])
# mosaic = create_cloud_free_mosaic(aoi, '2023-06-01', '2023-07-01')
# print(mosaic.getInfo())
# ```

# %%
#nwm jak inaczej to zrobłem z s2cloudless
from geoapps.lab03.cloud_mosaic import display_cloud_map, display_cloud_free_mosaic

# Wyświetlenie mapy z maską chmur
display_cloud_map()

# Wyświetlenie mozaiki bezchmurowej
display_cloud_free_mosaic()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# c:\Users\barto\miniconda3\envs\eo_lab\lib\site-packages\ee\deprecation.py:207: DeprecationWarning:
#
# Attention required for COPERNICUS/S2_SR! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR
#
#   warnings.warn(warning, category=DeprecationWarning)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ee96a3e3371f933ec85d80dbbae4051 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ee96a3e3371f933ec85d80dbbae4051&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ee96a3e3371f933ec85d80dbbae4051 = L.map(
#                 &quot;map_9ee96a3e3371f933ec85d80dbbae4051&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_541b8dff1d9f285bfdc33d5ac5730315 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_541b8dff1d9f285bfdc33d5ac5730315.addTo(map_9ee96a3e3371f933ec85d80dbbae4051);
#
#
#             var tile_layer_57e935982b457642f8be3f924add08ae = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/9e785fec3d681a30af25f13ab1c3233a-0967aad332fe415bea0fa6c7e50299fa/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57e935982b457642f8be3f924add08ae.addTo(map_9ee96a3e3371f933ec85d80dbbae4051);
#
#
#             var tile_layer_9c5ec8789a3f606d87470e20197f6df9 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/5af907364ab946017789e46f3b00b40c-42f790e2ca697f6e0a94df96e22dc530/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_a13fb532228b6915ecf8456cd92bfef9 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/2c9e25599a99972b8416540fdbe4261d-bdd47292b10a8e88ceebb7f8a1bc6a77/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_6b8329eaa92ea961405445573d4db9b1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/55388a31949a96a589093b560d65d96b-e1d26c37153b92632350b0284a4585a8/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_b264e612763ec0840e6165fd52abfdd1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/9fa96e471ce7ba06ee60bacec8937745-ef5dbaa4860cf433f583eb19012bf1d0/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_3747760738d0416e58d81cea0af85a72 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/c75bbb8dfc82aa313dfd168658dd84a1-eb5bb537784b003861bab35dbedfa7ca/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             var tile_layer_68fd225f239e7af19fc4bbedeb45d429 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/bad1789a369c
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_277df5957fe4ddbeff5eb1b4b4f5f7c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_277df5957fe4ddbeff5eb1b4b4f5f7c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_277df5957fe4ddbeff5eb1b4b4f5f7c2 = L.map(
#                 &quot;map_277df5957fe4ddbeff5eb1b4b4f5f7c2&quot;,
#                 {
#                     center: [50.09997336373202, 19.899999999999498],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c31fae709d435d46e0cacd293e9108e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c31fae709d435d46e0cacd293e9108e6.addTo(map_277df5957fe4ddbeff5eb1b4b4f5f7c2);
#
#
#             var tile_layer_92467eb6c8fe1fd6dccfe7ccc4f20a16 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-skoraremotesensing/maps/07a9304f03073ffeee4402fc55dea3bd-f170a5b054f3e1c9c2836332222b38fb/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map Data \u00a9 Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92467eb6c8fe1fd6dccfe7ccc4f20a16.addTo(map_277df5957fe4ddbeff5eb1b4b4f5f7c2);
#
#
#             var layer_control_8ebc6da1f441a7ddfe4d3512d5ac7cea_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c31fae709d435d46e0cacd293e9108e6,
#                 },
#                 overlays :  {
#                     &quot;S2 cloud-free mosaic&quot; : tile_layer_92467eb6c8fe1fd6dccfe7ccc4f20a16,
#                 },
#             };
#             let layer_control_8ebc6da1f441a7ddfe4d3512d5ac7cea = L.control.layers(
#                 layer_control_8ebc6da1f441a7ddfe4d3512d5ac7cea_layers.base_layers,
#                 layer_control_8ebc6da1f441a7ddfe4d3512d5ac7cea_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_277df5957fe4ddbeff5eb1b4b4f5f7c2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Step 6: Bonus – Add a Demo Notebook
# Create a notebook in a separate `notebooks/` folder where you import and visualize the result using `geemap`:
#
# ```python
# import geemap
# Map = geemap.Map(center=[50.1, 19.9], zoom=10)
# Map.addLayer(mosaic, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Mosaic')
# Map
# ```
